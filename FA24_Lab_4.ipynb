# %% [markdown]
# <a href="https://colab.research.google.com/github/kohncory/Teaching_R_Sample/blob/main/FA24_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BIOL 175 - Colab 4 (Chapter 3)
# # Making data files for R and Sampling
#
# This file, made by Dr. Cory Kohn (Scripps and Pitzer Colleges), was originally based on tutorial 4a and 4b for the Analysis of Biological Data Labs available [here](https://whitlockschluter3e.zoology.ubc.ca/RLabs/R_tutorial_Making_data_files.html) and [here](https://whitlockschluter3e.zoology.ubc.ca/RLabs/R_tutorial_Sampling.html).
#
# ###Learning outcomes:
# *   Learn to create data files for R.
# *   Explore the importance of random sampling.
# *   Understand the sampling distribution of an estimate.
# *   Investigate sampling error and sampling bias.
# *   Practice creating data files.

# %% [markdown]
# ## Learning the tools

# %% [markdown]
# ### The structure of a good data file
# Data files appear in many formats, and different formats are sometimes preferable for different tasks. But there is one way to structure data—called “long” format—that is extremely useful for most things that you will want to do in statistics and R.
#
# Long format is actually very simple. Every row in the data set is a unique individual. Every column is a variable being measured on those individuals.
#
# For example, in lab 3 Question 5 we looked at some data about the tongue and palate lengths of several species of bats. There were three variables in that data set, the species name, tongue length, and palate length. Here each “individual” is a species. Here is that data in long format—each row is an individual. There are three columns, one for each variable:
# ![Long data format.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Creating a data file
#
# When you have new data that you want to get into the computer in a format that R can read, it is often easiest to do this outside of R. A spreadsheet program like Excel (or a freely available program like OpenOffice Calc or Google Sheets) is a straightforward way to create a .csv file that R can read. **For Mac users**, I don't recommend the program Numbers for creating, editing, or even opening just to view .csv files. If your computer opens .csv files in Numbers by default, I recommend changing the default setting to any other program.
#
# In your spreadsheet program, open a new (i.e., empty) file. In the first row of your new spreadsheet, write your variable names, one for each column. Be sure to give them good names that will work in R. Most importantly, don’t have any spaces in a variable name and make sure that it doesn’t start with a number or contain punctuation marks. (See Lab 1 for more about naming variables.)
#
# On the rows immediately below that first row, enter the data for each individual, in the correct column. Here’s what the spreadsheet would look like for the bat data after they are entered:
#
# ![spreadsheet view.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Saving as a .csv file
# Saving a spreadsheet in a format that R can read is straightforward once you understand that you can save files into one of several differment format options. In these labs, we are using .csv files (which stands for comma separated values). Once you have made your spreadsheet, under the “File” (or equivalent) menu click on “Save as…” (or the equivalent option in your program). This will open a dialog box. First, give the file a name with the extension .csv at the end. We used “BatTongues.csv”. Then choose what folder you want to save the file in.
#
# Finally, choose the correct format for the file. The right format is “Comma separated values” which you can choose from after "Format:" (or the equivalent option) in the dialog box. It might look something like this:
#
# ![format csv.jpg](data:image/jpeg;base64,...)
#
# **Note** there might be several .csv options. If so, choose the format that is *most* general (not specific to an operating system or encoding standard). For example, if your options are "CSV UTF-8" or "CSV" or "CSV (Macintosh)" then choose the most general option (the middle choice in this list).

# %% [markdown]
# In the resulting file, the first line will be a header that lists the names of each column (i.e., variable). After that there will be one line for each individual. All the variable names in the first row and the variable values in the later rows will be separated by commas, hence the name of the format. If you opened the .csv file in a simple text editor (e.g., Wordpad, Notepad, Notepad++) it would look like this:
#
# ---
# species,palate_length,tongue_length
#
# Lichonycteris obscura,10,36.1
#
# Glossophaga comissarisi,10.7,26.6
#
# Glossophaga soricina,11.4,30.2
#
# Anoura caudifer,11.6,36.7
#
# Hylonycteris underwoodi,13.4,36.7
#
# Anoura geoffroyi,13.8,39.6
#
# Lonchophylla robusta,14.3,42.6
#
# Anoura fistulata,12.4,85.2
#
# Anoura cultrata,14.3,34.3
#
# Leptonycteris curosoae,16,40.2
#
# Choeronycteris mexicana,18,52.1
#
# ---
#
# All the information is there, and it is stored in a simple text file that can be read again by Excel or R or many other programs.

# %% [markdown]
# ## Activities and Questions
# For each lab, add new code **and** text boxes (or **`#`**-marked comments within code boxes) to the bottom and/or within the tutorial to practice the activities.
#
# In this lab you will be given a container of 25 cowrie shells. Think of this collection of shells as the complete population that you care about. You will work with a small group to take samples from this population to estimate the mean length of these shells.
#
# Follow these steps:

# %% [markdown]
# ### Make a sample -- Steps 1-5
# *   Get a piece of calendar paper, and make sure that there are spots labeled from 1 to 25 on squares of the calendar paper.
#
# *   Sample five shells from this container. Put them in spots 1 through 5 on the paper. This is your sample.
#
# *   For each shell that you have sampled, measure the length of the shell in millimeters, and write these lengths down on the paper by that shell.
#
# *   Open a new data file in a spreadsheet program (e.g., Excel, Sheets), and on the first row add a variable name (e.g., “length”). Enter the lengths of your five shells. Save the file with a title something like “First_sample.csv”. (See the sections in this lab above for guidance regarding creating and saving a .csv file.)
#
# *   Import this first sample data into R (see Lab 2, reading a file). Using R, calculate the mean of the lengths of these five shells. Record this mean.

# %% [markdown]
# ### Find the mean of the population -- Steps 6-9
# *   Next we will calculate the mean of the population of shells in your container. Take each remaining shell one by one, measure its length, and record it on the sheet beside the next available number. Set the shell there on the calendar paper as well.
#
# *   Open another data file in the spreadsheet program. Add the lengths of all the shells (including the first five) into this file in a single column named “length.” Save this file with a title of something like “Full_population_shells.csv”.
#
# *   Import this data set to R. Load the csv file after you have uploaded it to your session storage. Name this as you like, but later in these instructions we will refer to the imported R object as “**`population_data`**”. Use R to calculate the mean of the full population.
#
# *   Add the **mean** of your first sample and the **mean** of your population to the vectors in Prof Kohn's version of Colab 4 using his laptop, groups_first_sample = c(...) and
# groups_pop_mean = c(...), for full class use in steps 18-19.

# %%
# Send a group representative to type your group's calculated values into Prof Kohn's version of Colab 4 using his laptop
groups_first_sample = c(22.1, 22.3, 22.6, 21.6, 22.6, 22.6, 22.6) # Come up and enter your group's first sample mean when you have it
groups_pop_mean = c(22.0, 21.08, 22.748, 23.24, 22.44, 22.28, 22.4)     # Come up and enter your group's population mean when you have it

# %% [markdown]
# ###***Complete up to here, step 9, during class. The rest can be completed outside of class.***
# ###***Make sure you share the .csv files you created with all group members.***

# %% [markdown]
# ###Question 1
# Is the mean of your sample the same as the mean of your population as a whole? Suggest reasons why the sample mean and the population mean might differ.

# %% [markdown]
# ### Make a random sample and estimate the population mean -- Steps 10-12
# *   In step 1, we made a sample, but it was not necessarily a random sample. Let’s now randomly sample from the population. You should have each shell next to a unique number on your sheet. To take a random sample, all members of the population must have the same chance of being chosen for our sample. In R, the function `sample.int()` randomly chooses integers from a given range. To randomly sample 5 individuals from 25 possibilities, we can use:

# %%
sample.int(n = 25, size = 5)
# Out:
# [1] 19  6 25 20  4

# %% [markdown]
# This tells R to give us a set of 5 numbers randomly chosen from the integers 1 to 25. (When you run this line you will almost certainly get a different output. It is randomly choosing numbers, so we expect different answers each time.) Generate a set of 5 random numbers this way. Use these numbers to tell you which 5 shells to include in your sample.
#
# *   Use R to calculate the mean of the shell lengths for these 5 shells in your random sample. The result is an estimate of the mean shell length in your population.
#
# *   Make another random sample of 5 shells, and calculate the mean of this sample. Did you get a different number from the mean of the first sample? Why do you think the second sample mean is different from the first?

# %% [markdown]
# ### Making a distribution of sample means -- Steps 13-16
# The estimates you obtained from your random samples in steps 11 and 12 are just two of many values that you might have obtained. By chance, each sample is likely to be different from other samples, with a different sample mean. The frequency distribution of estimates that you might obtain when sampling randomly from a population, and their probabilities of occurrence, is called the sampling distribution of the estimate. To explore the sampling distribution for the sample mean, let’s randomly sample from your population of shells several times. Each sample is going to have five shells, and we’ll calculate the mean of each sample.
#
# In real life situations, you won’t have the whole population to work with, and you won’t be able to take many random samples. As a result, you won’t be able to glimpse the sampling distribution. But in this artificial scenario we can create multiple samples from our population to see what the sampling distribution might look like.
#
# *   Taking each sample by hand is tedious. To speed up this process, we have written a short R function to sample from your list of shell lengths in your population. This will have the computer do the steps that you did in the previous steps.
#
# The function is called **`mean_from_a_sample`**, and it is defined in the cell below. Execute the cell to define this function for your R environment, but comment out the **`population data = line`** if you already stored your data as this variable in code you added above.

# %%
#  Sampling

# Let's write a function to speed up the lab, which takes a data frame
# with some number of shell measurements and:
#    (1) Sample x individuals by row,
#    (2) Display the measures for those rows, and
#    (3) Calculate the mean of those measures

# For the following function "mean_from_a_sample", datalist should be a column
# that gives a list of a single numerical variable over a number of individuals.
# This will represent the population from which the sample is taken.

# sample_size is the number of individuals that you want to have in the sample

mean_from_a_sample <- function(datalist, sample_size) {
  population_size = length(datalist)  # Establish the size of the "population"
  sample_numbers = sample.int(population_size, sample_size)  # chooses which individuals to sample
  sample_values = datalist[sample_numbers]  # Looks up the values for those individuals in the data
  sample_mean = mean(sample_values, na.rm=TRUE)   # Calculates the mean of those sampled individuals
  sample_mean
}

# %% [markdown]
# Call this function by entering:

# %%
mean_from_a_sample(population_data$length, sample_size = 5)

# %% [markdown]
# where “**`population_data$length`**” is the vector of all the lengths of the shells from your population, and 5 is the sample size. If your dataframe and/or the name of your variable in the dataframe are called something different, then modify the code so you call is accurate for your code. For example:
#
# ```
# # mean_from_a_sample(PopulationData$Length, sample_size = 5) # modify the DataFrame$VariableName
# ```
#
# Running this will give you the mean length of a random sample of 5 shells.
#
# *   To make a vector with the means of 1000 random samples of the shell lengths, run the following (this is a "for loop"):

# %%
sample_mean_length = rep(0,1000)  # Initiate a vector of one thousand zeroes as placeholders
for (i in 1:1000){
  sample_mean_length[i] = mean_from_a_sample(population_data$length,5) # Assign the function's output to each position in vector
}

# %% [markdown]
# This creates a vector called **`sample_mean_length`** and fills it with 1000 means of independent random samples.
#
# *   Plot a histogram that shows the distribution of the means of these random samples. (Note: in order to use ggplot to make a histogram, the data have to be in a data frame. Use the line of code below to change your vector into a data frame.)

# %%
samples = data.frame(meanLength=sample_mean_length)

# %% [markdown]
# ### Question 2
# Describe the shape of this distribution. Does it resemble a normal distribution? Does every sample return the same value of the mean? Why, or why not?

# %% [markdown]
# *   Calculate the mean of the distribution of sample means.

# %% [markdown]
# ### Question 3
# How does the mean of the distribution of sample means compare to the true mean of the population? Are they approximately equal? Are your sample means unbiased estimates of the population mean?

# %% [markdown]
# ### Sampling bias -- Steps 17-19
# *   Compare the mean of your first sample to the distribution of sample means obtained from the random samples. Is your first sample mean unusual in any way?
#
# *   Get the list of the means from the first samples of each group, and the population means for each group, **`groups_first_sample = c(...)`** and **`groups_pop_mean = c(...)`**, respectfully. This is from step 9, above.
#
# *   Create a new variable from the difference between a student group’s first sample mean and their population mean. Call this new variable **`first_sample_error`**. What is the average error of these first samples?

# %% [markdown]
# ###Question 4
# Remember that these first samples were not necessarily random samples, unlike the other samples that we made today. Is there any pattern to the first samples that you think might result from this lack of randomness? If so, why might this have happened?
